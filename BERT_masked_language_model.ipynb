# %% [markdown]
# <a href="https://colab.research.google.com/github/drashyabansel/GenerativeAI/blob/main/BERT_masked_language_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline

# %%
unmasker = pipeline("fill-mask")
# Out:
# No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8 (https://huggingface.co/distilbert/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/331M [00:00<?, ?B/s]
# ...

# %%
unmasker("I am trying to <mask> python to get a job as data scientist")
# Out:
# [{'score': 0.5748016834259033,
#   'token': 1532,
#   'token_str': ' learn',
#   'sequence': 'I am trying to learn python to get a job as data scientist'},
#  {'score': 0.09051971882581711,
#   'token': 6396,
#   'token_str': ' teach',
#   'sequence': 'I am trying to teach python to get a job as data scientist'},
#  {'score': 0.0859762653708458,
#   'token': 304,
#   'token_str': ' use',
#   'sequence': 'I am trying to use python to get a job as data scientist'},
#  {'score': 0.04408495873212814,
#   'token': 14157,
#   'token_str': ' hack',
#   'sequence': 'I am trying to hack python to get a job as data scientist'},
#  {'score': 0.02029029093682766,
#   'token': 6270,
#   'token_str': ' leverage',
#   'sequence': 'I am trying to leverage python to get a job as data scientist'}]

# %%
unmasker("I am trying to master python to get a job as <mask>")
# Out:
# [{'score': 0.14490292966365814,
#   'token': 157,
#   'token_str': ' well',
#   'sequence': 'I am trying to master python to get a job as well'},
#  {'score': 0.05685785785317421,
#   'token': 38988,
#   'token_str': ' programmer',
#   'sequence': 'I am trying to master python to get a job as programmer'},
#  {'score': 0.050141528248786926,
#   'token': 19552,
#   'token_str': ' Administrator',
#   'sequence': 'I am trying to master python to get a job as Administrator'},
#  {'score': 0.03436587005853653,
#   'token': 1324,
#   'token_str': ' CEO',
#   'sequence': 'I am trying to master python to get a job as CEO'},
#  {'score': 0.032125331461429596,
#   'token': 28665,
#   'token_str': ' admin',
#   'sequence': 'I am trying to master python to get a job as admin'}]

# %%
unmasker("I am trying to learn python to get a job as data <mask>")
# Out:
# [{'score': 0.31668686866760254,
#   'token': 2066,
#   'token_str': ' analyst',
#   'sequence': 'I am trying to learn python to get a job as data analyst'},
#  {'score': 0.23743396997451782,
#   'token': 9744,
#   'token_str': ' scientist',
#   'sequence': 'I am trying to learn python to get a job as data scientist'},
#  {'score': 0.04667827486991882,
#   'token': 1044,
#   'token_str': ' manager',
#   'sequence': 'I am trying to learn python to get a job as data manager'},
#  {'score': 0.0337248221039772,
#   'token': 37764,
#   'token_str': ' logger',
#   'sequence': 'I am trying to learn python to get a job as data logger'},
#  {'score': 0.03246917948126793,
#   'token': 22779,
#   'token_str': ' collector',
#   'sequence': 'I am trying to learn python to get a job as data collector'}]

# %%
unmasker("I am trying to <mask> python to get a job as data <mask>")
# Out:
# [[{'score': 0.3381061851978302,
#    'token': 1532,
#    'token_str': ' learn',
#    'sequence': '<s>I am trying to learn python to get a job as data<mask></s>'},
#   {'score': 0.22701279819011688,
#    'token': 6396,
#    'token_str': ' teach',
#    'sequence': '<s>I am trying to teach python to get a job as data<mask></s>'},
#   {'score': 0.15265007317066193,
#    'token': 304,
#    'token_str': ' use',
#    'sequence': '<s>I am trying to use python to get a job as data<mask></s>'},
#   {'score': 0.05220193788409233,
#    'token': 14157,
#    'token_str': ' hack',
#    'sequence': '<s>I am trying to hack python to get a job as data<mask></s>'},
#   {'score': 0.029120609164237976,
#    'token': 6270,
#    'token_str': ' leverage',
#    'sequence': '<s>I am trying to leverage python to get a job as data<mask></s>'}],
#  [{'score': 0.20882469415664673,
#    'token': 2066,
#    'token_str': ' analyst',
# ...

# %%
unmasker = pipeline("fill-mask", "bert-base-uncased")
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# ...

# %%
unmasker("I am trying to <mask> python to get a job as data scientist")
# Out:
# ---------------------------------------------------------------------------
# PipelineException                         Traceback (most recent call last)
# <ipython-input-9-42afff52e904> in <cell line: 0>()
# ----> 1 unmasker("I am trying to <mask> python to get a job as data scientist")
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/fill_mask.py in __call__(self, inputs, **kwargs)
#     268             - **token_str** (`str`) -- The predicted token (to replace the masked one).
#     269         """
# --> 270         outputs = super().__call__(inputs, **kwargs)
#     271         if isinstance(inputs, list) and len(inputs) == 1:
#     272             return outputs[0]
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1377             )
#    1378         else:
# -> 1379             return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
# ...

# %%
unmasker("I am trying to [MASK] python to get a job as data scientist")

# %%
unmasker("I am trying to [MASK] python to get a job as data [MASK]")
# Out:
# [[{'score': 0.8705468773841858,
#    'token': 2224,
#    'token_str': 'use',
#    'sequence': '[CLS] i am trying to use python to get a job as data [MASK] [SEP]'},
#   {'score': 0.04776865243911743,
#    'token': 4553,
#    'token_str': 'learn',
#    'sequence': '[CLS] i am trying to learn python to get a job as data [MASK] [SEP]'},
#   {'score': 0.010493631474673748,
#    'token': 6570,
#    'token_str': 'teach',
#    'sequence': '[CLS] i am trying to teach python to get a job as data [MASK] [SEP]'},
#   {'score': 0.0059374114498496056,
#    'token': 2131,
#    'token_str': 'get',
#    'sequence': '[CLS] i am trying to get python to get a job as data [MASK] [SEP]'},
#   {'score': 0.002881752559915185,
#    'token': 2202,
#    'token_str': 'take',
#    'sequence': '[CLS] i am trying to take python to get a job as data [MASK] [SEP]'}],
#  [{'score': 0.9807263016700745,
#    'token': 1012,
#    'token_str': '.',
# ...

# %%
unmasker = pipeline("fill-mask", "bert-large-uncased")
# Out:
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# ...

# %%
unmasker("I am trying to [MASK] python to get a job as data scientist")
# Out:
# [{'score': 0.3449562191963196,
#   'token': 2224,
#   'token_str': 'use',
#   'sequence': 'i am trying to use python to get a job as data scientist'},
#  {'score': 0.09244611859321594,
#   'token': 2681,
#   'token_str': 'leave',
#   'sequence': 'i am trying to leave python to get a job as data scientist'},
#  {'score': 0.0632893368601799,
#   'token': 2377,
#   'token_str': 'play',
#   'sequence': 'i am trying to play python to get a job as data scientist'},
#  {'score': 0.05887557938694954,
#   'token': 8046,
#   'token_str': 'quit',
#   'sequence': 'i am trying to quit python to get a job as data scientist'},
#  {'score': 0.054566673934459686,
#   'token': 4553,
#   'token_str': 'learn',
#   'sequence': 'i am trying to learn python to get a job as data scientist'}]
